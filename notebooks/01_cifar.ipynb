# %% [markdown]
# # THE CIFAR DATASET

# %%
from importlib.util import find_spec
if find_spec("model") is None:
    import sys
    sys.path.append('..')

# %%
import numpy as np
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from PIL import Image

# %%
train_trsfms = transforms.Compose([transforms.ToTensor()])

# %%
def print_normal(dataset):
    print(f"shape of train data: {dataset.data.shape}")
    print(f"mean of train data: {dataset.data.mean(axis=(0, 1, 2)) / 255}")
    print(f"std of train data: {dataset.data.std(axis=(0, 1, 2)) / 255}")

# %%
def plot_four(dataset):
    fig = plt.figure()
    for i in range(4):
        ax = fig.add_subplot(2, 2, i + 1)
        ax.imshow(train_set[i][0].permute(1, 2, 0))

# %% [markdown]
# ## CIFAR10 Normalization

# %%
train_set = datasets.CIFAR10('./data', train=True, download=True, transform=train_trsfms)
# Out:
# Files already downloaded and verified

# %%
print_normal(train_set)
# Out:
# shape of train data: (50000, 32, 32, 3)
# mean of train data: [0.49139968 0.48215841 0.44653091]
# std of train data: [0.24703223 0.24348513 0.26158784]

# %%
train_set[0][0].shape, train_set[0][1]
# Out:
# (torch.Size([3, 32, 32]), 6)

# %%
train_set[1][0].shape
# Out:
# torch.Size([3, 32, 32])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax1.imshow(train_set[0][0].permute(1, 2, 0))

# %%
plot_eight(train_set)

# %% [markdown]
# ## CIFAR100 Normalization

# %%
train_set = datasets.CIFAR100('./data', train=True, download=True, transform=train_trsfms)
# Out:
# ...
# Extracting ./data/cifar-100-python.tar.gz to ./data

# %%
print_normal(train_set)
# Out:
# shape of train data: (50000, 32, 32, 3)
# mean of train data: [0.50707516 0.48654887 0.44091784]
# std of train data: [0.26733429 0.25643846 0.27615047]

# %%
plot_eight(train_set)
